# %%
# 불과 비교 연산자 사용하기

True
False
# Out:
# False

# %%
# 비교 연산자의 판단 결과

3 > 1
# Out:
# True

# %%
# 숫자가 같은지 비교
3==3
# Out:
# True

# %%
print("Python"=="Python")
print("Python"=="python")
print("Python"!="python") # <>
# Out:
# True
# False
# True

# %%
# 부등호 사용하기
print(10 > 20)
print(10 > 20)
print(10 <= 10)
print(10 >= 10)
# Out:
# False
# False
# True
# True

# %%
# 객체가 같은지 다른지 비교하기
print(1 == 1.0)
print(1 is 1.0)
# Out:
# True
# False
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_16832\2845622414.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(1 is 1.0)

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
1 is not 1.0
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_16832\2095918375.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   1 is not 1.0
# True

# %%
# 논리 연산자 사용하기 
## AND
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
# OR 연산자
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
not True and False or not False
# Out:
# True

# %%
((not True) and False) or (not False)
# Out:
# True

# %%
# 논리 연산자와 비교 연산자 사용, 비교 연산자가 우선순위이다. 정수에서 0을 제외하고는 기존에는 다 True 취급이다.

print((10 == 10) and (10 != 5))

print((10 > 5) or (10<3))

print(not 10>5)
print(not 1 is 1.0)
# Out:
# True
# True
# False
# True
# <>:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Win11Pro\AppData\Local\Temp\ipykernel_16832\1745769056.py:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(not 1 is 1.0)

# %%
not 0
# Out:
# True

# %%
# 8.3
c
d
b, c
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # 8.3
# ----> 2 c
#       3 d
#       4 b, c
#       5 d
#
# NameError: name 'c' is not defined

# %%
korean = 92
english = 47
mathematics=86
science = 81
print(korean>= 50 and english >= 50 and mathematics >=50 and science>=50)
# Out:
# False

# %%
a,b,c,d= map(int, input("국어, 영어, 수학, 과학 점수를 입력하세요:").split())
print
