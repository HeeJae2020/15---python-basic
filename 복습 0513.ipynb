# %%
a, b, c = map(int, input().split())
print(a+b+c)

# %%
i = 2
j = 5
while i <= 32 or j==1:
    i*=2
    j-=1
    print(i,j)

# %%
money = int(input("잔액을 입력하세요:"))
while money<0:
    print(money-1350)
