# %%
hello = "Hello World"
hello
hello = "안녕하세요"
hello
# Out:
# '안녕하세요'

# %%
hello = '''Hello World!'''
hello
# Out:
# 'Hello World!'

# %%
python = """python programming"""
python
# Out:
# 'python programming'

# %%
# 여러 줄로 된 문자 열 사용하기
hello = '''Hello, World!
안녕하세요
Python입니다.'''
print(hello)
# Out:
# Hello, World!
# 안녕하세요
# Python입니다.

# %%
# 문자열 안에 작은따옴표나 큰 따옴표 포함하기
s = "Python isn't difficult"
s
# Out:
# "Python isn't difficult"

# %%
s = "he said \" python is easy\""
s
# Out:
# 'he said " python is easy"'

# %%
# 9.2
1. b, d
2. a, c
3. a, c, d
# Out:
#   Cell In[11], line 2
#     1. b, d
#        ^
# SyntaxError: invalid syntax

# %%
d = "Python is a progamming language that lets you work quickly \nand\nintegrate systems more effectively"
print(d)
# Out:
# Python is a progamming language that lets you work quickly
# and
# integrate systems more effectively

# %%
s= ''''Python' is a "programming language"
that lets you work quickly
and
integrate systems more effectively'''
print(s)
# Out:
# 'Python' is a "programming language"
# that lets you work quickly
# and
# integrate systems more effectively
