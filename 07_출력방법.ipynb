# %%
# 값을 여러 개 출력하기
print(1, 2, 3)
# Out:
# 1 2 3

# %%
# sep로 값 사이에 문자 넣기 sep= "" <-""사이에 있는 것으로 분리
print(1, 2, 3, sep=", ")
# Out:
# 1, 2, 3

# %%
print(1920, 1000, sep="X")
# Out:
# 1920X1000

# %%
# 줄바꿈 활용하기
print(1, 2, 3, sep="\n")
# Out:
# 1
# 2
# 3

# %%
print("1\n2\n3")
# Out:
# 1
# 2
# 3

# %%
# end 사용하기
print(1)
print(2)
print(3)
# Out:
# 1
# 2
# 3

# %%
print(1, end="")
print(2, end="")
print(3)
# Out:
# 123

# %%
print(1, end=" ")
print(2, end=" ")
print(3)

print(1, 2, 3)
# Out:
# 1 2 3
# 1 2 3

# %%
# 7.3
1.d
2.c
3.b,d,e
# Out:
#   Cell In[11], line 2
#     1.d
#      ^
# SyntaxError: invalid decimal literal

# %%
# 7.4
year = 2000
month= 10
day= 27
hour = 11
minute=43
second=59
print( year, month, day, sep="/", end=' ')
print(hour, minute, second, sep=":")
# Out:
# 2000/10/27 11:43:59
