# %%
import turtle as t

t.shape("turtle")

# %%
import turtle as t
t.forward(100)

# %%
import turtle as t
t.forward(1000)

# %%
t.right(90)

# %%
t.forward(90)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 t.forward(90)
#
# NameError: name 't' is not defined

# %%
import turtle as t
t.shape("turtle")
for i in range(4):
    t.forward(100)
    t.right(90)

# %%
t.clear()

# %%
# 오각형 만들기
import turtle as t
n = 6
t.shape("turtle")
for i in range(5):
    t.forward(100)
    t.right(360/5)

# %%
# 다각형에 색칠하기
import turtle as t

n = 6
t.shape("turtle")
t.color("red")
t.begin_fill()
for i in range(5):
    t.forward(100)
    t.right(360/5)
t.end_fill()

# %%
import turtle as t

t.shape("turtle")
t.circle(120)

# %%
t.clear()

# %%
# 원을 반복해서 그리기
import turtle as t

n = 60
t.shape("turtle")
t.speed("fastest")
for i in range(n):
    t.circle(120)
    t.right(360/n)

# %%
t.clear()

# %%
# 선으로 복잡한 무늬 그리기
import turtle as t

t.shape("turtle")
t.speed("fastest")
for i in range(720):
    t.forward(i)
    t.right(91)
